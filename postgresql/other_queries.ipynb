# %%
import pandas as pd
import psycopg
from env import CONNECTION_STRING

# %% [markdown]
# #### Connect to Database

# %%
conn = psycopg.connect(CONNECTION_STRING)

# %% [markdown]
# #### Get Database Cursor

# %%
cur = conn.cursor()

# %% [markdown]
# #### Variables

# %%
movie_columns = ['id', 'title', 'industry', 'release_year',
                 'imdb_rating', 'studio', 'language_id']

# %% [markdown]
# #### Select All Movies

# %%
movies = cur.execute('''
    SELECT * FROM movies;
''').fetchall()

df = pd.DataFrame(movies, columns=movie_columns)
df
# Out:
#      id  ... language_id
# 0   101  ...           3
# 1   102  ...           5
# 2   103  ...           5
# 3   104  ...           5
# 4   105  ...           5
# 5   106  ...           1
# 6   107  ...           1
# 7   108  ...           1
# 8   109  ...           1
# 9   110  ...           1
# 10  111  ...           5
# 11  112  ...           5
# 12  113  ...           5
# 13  115  ...           5
# 14  116  ...           5
# 15  117  ...           5
# 16  118  ...           5
# 17  119  ...           5
# 18  120  ...           5
# 19  121  ...           5
# 20  122  ...           5
# 21  123  ...           5
# 22  124  ...           5
# 23  125  ...           5
# 24  126  ...           5
# 25  127  ...           7
# 26  128  ...           1
# 27  129  ...           1
# 28  130  ...           1
# 29  131  ...           1
# 30  132  ...           2
# 31  133  ...           2
# 32  134  ...           2
# 33  135  ...           1
# 34  136  ...           1
# 35  137  ...           5
# 36  138  ...           5
# 37  139  ...           1
# 38  140  ...           1
#
# [39 rows x 7 columns]

# %% [markdown]
# #### Select All Movies But Ordered

# %%
movies = cur.execute('''
    SELECT * FROM movies ORDER BY imdb_rating DESC;
''').fetchall()

df = pd.DataFrame(movies, columns=movie_columns)
df
# Out:
#      id  ... language_id
# 0   131  ...           1
# 1   111  ...           5
# 2   120  ...           5
# 3   122  ...           5
# 4   121  ...           5
# 5   112  ...           5
# 6   118  ...           5
# 7   113  ...           5
# 8   116  ...           5
# 9   124  ...           5
# 10  140  ...           1
# 11  108  ...           1
# 12  125  ...           5
# 13  126  ...           5
# 14  101  ...           3
# 15  135  ...           1
# 16  128  ...           1
# 17  127  ...           7
# 18  123  ...           5
# 19  136  ...           1
# 20  129  ...           1
# 21  106  ...           1
# 22  130  ...           1
# 23  134  ...           2
# 24  107  ...           1
# 25  133  ...           2
# 26  115  ...           5
# 27  117  ...           5
# 28  104  ...           5
# 29  138  ...           5
# 30  119  ...           5
# 31  132  ...           2
# 32  109  ...           1
# 33  110  ...           1
# 34  102  ...           5
# 35  137  ...           5
# 36  105  ...           5
# 37  103  ...           5
# 38  139  ...           1
#
# [39 rows x 7 columns]

# %% [markdown]
# #### Select Movies But Limited

# %%
movies = cur.execute('''
    SELECT * FROM movies
        ORDER BY imdb_rating ASC
        LIMIT 5;
''').fetchall()

df = pd.DataFrame(movies, columns=movie_columns)
df
# Out:
#     id  ... language_id
# 0  139  ...           1
# 1  103  ...           5
# 2  105  ...           5
# 3  137  ...           5
# 4  102  ...           5
#
# [5 rows x 7 columns]

# %% [markdown]
# #### Commit Queries

# %%
conn.commit()

# %% [markdown]
# #### Close the Cursor and Connection

# %%
cur.close()
conn.close()
