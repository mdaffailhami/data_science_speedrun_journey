# %%
import pandas as pd

# %%
df = pd.read_csv('Flavors.csv')
df.head(1)
# Out:
#                 Flavor Base Flavor Liked  Flavor Rating  Texture Rating  \
# 0  Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
#
#    Total Rating
# 0          18.0

# %% [markdown]
# #### Rename columns label

# %%
df = df.rename(columns=lambda col: col.lower().replace(' ', '_'))
df
# Out:
#                    flavor base_flavor liked  flavor_rating  texture_rating  \
# 0     Mint Chocolate Chip     Vanilla   Yes           10.0             8.0
# 1               Chocolate   Chocolate   Yes            8.8             7.6
# 2                 Vanilla     Vanilla    No            4.7             5.0
# 3            Cookie Dough     Vanilla   Yes            6.9             6.5
# 4              Rocky Road   Chocolate   Yes            8.2             7.0
# 5               Pistachio     Vanilla    No            2.3             3.4
# 6             Cake Batter     Vanilla   Yes            6.5             6.0
# 7              Neapolitan     Vanilla    No            3.8             5.0
# 8  Chocolte Fudge Brownie   Chocolate   Yes            8.2             7.1
#
#    total_rating
# 0          18.0
# 1          16.6
# 2           9.7
# 3          13.4
# 4          15.2
# 5           5.7
# 6          12.5
# 7           8.8
# 8          15.3

# %%
# Specific column
df.groupby('base_flavor')['texture_rating'].mean()
# ===
# df.groupby('base_flavor').mean(numeric_only=True)['texture_rating']
# Out:
# base_flavor
# Chocolate    7.233333
# Vanilla      5.650000
# Name: texture_rating, dtype: float64

# %%
# All columns with numeric dtype
df.groupby('base_flavor').mean(numeric_only=True)
# Out:
#              flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate              8.4        7.233333         15.70
# Vanilla                5.7        5.650000         11.35

# %%
df.groupby('base_flavor').count()
# Out:
#              flavor  liked  flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate         3      3              3               3             3
# Vanilla           6      6              6               6             6

# %%
# Note: for strings, it'll based on alphabetical order
# Why Chocolate liked is yes? It's because there is "No" in table for Chocolate
df.groupby('base_flavor').min()
# Out:
#                   flavor liked  flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate      Chocolate   Yes            8.2             7.0          15.2
# Vanilla      Cake Batter    No            2.3             3.4           5.7

# %%
df.groupby('base_flavor').max()
# Out:
#                  flavor liked  flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate    Rocky Road   Yes            8.8             7.6          16.6
# Vanilla         Vanilla   Yes           10.0             8.0          18.0

# %%
df.groupby('base_flavor').max(numeric_only=True)
# Out:
#              flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate              8.8             7.6          16.6
# Vanilla               10.0             8.0          18.0

# %%
df.groupby('base_flavor').sum()
# Out:
#                                                         flavor  \
# base_flavor
# Chocolate            ChocolateRocky RoadChocolte Fudge Brownie
# Vanilla      Mint Chocolate ChipVanillaCookie DoughPistachi...
#
#                        liked  flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate          YesYesYes           25.2            21.7          47.1
# Vanilla      YesNoYesNoYesNo           34.2            33.9          68.1

# %%
df.groupby('base_flavor').sum(numeric_only=True)
# Out:
#              flavor_rating  texture_rating  total_rating
# base_flavor
# Chocolate             25.2            21.7          47.1
# Vanilla               34.2            33.9          68.1

# %% [markdown]
# #### Multi group

# %%
x = df.groupby(['base_flavor', 'liked']).mean(numeric_only=True)

display(x.index)
display(x)
# Out:
# MultiIndex([('Chocolate', 'Yes'),
#             (  'Vanilla',  'No'),
#             (  'Vanilla', 'Yes')],
#            names=['base_flavor', 'liked'])
#                    flavor_rating  texture_rating  total_rating
# base_flavor liked
# Chocolate   Yes              8.4        7.233333     15.700000
# Vanilla     No               3.6        4.466667      8.066667
#             Yes              7.8        6.833333     14.633333

# %%
# Note: Order matters
df.groupby(['liked', 'base_flavor']).mean(numeric_only=True)
# Out:
#                    flavor_rating  texture_rating  total_rating
# liked base_flavor
# No    Vanilla                3.6        4.466667      8.066667
# Yes   Chocolate              8.4        7.233333     15.700000
#       Vanilla                7.8        6.833333     14.633333

# %% [markdown]
# #### Multi aggregation
#
# Note: agg() and aggregate() are the same

# %%
# All columns
df.groupby('base_flavor').agg(['max', 'min'])
# ===
# df.groupby('base_flavor').aggregate(['max', 'min'])
# Out:
#                  flavor              liked      flavor_rating       \
#                     max          min   max  min           max  min
# base_flavor
# Chocolate    Rocky Road    Chocolate   Yes  Yes           8.8  8.2
# Vanilla         Vanilla  Cake Batter   Yes   No          10.0  2.3
#
#             texture_rating      total_rating
#                        max  min          max   min
# base_flavor
# Chocolate              7.6  7.0         16.6  15.2
# Vanilla                8.0  3.4         18.0   5.7

# %%
# Specific columns
df.groupby('base_flavor').agg({
    # Use list atleast one column in order to make it uses 'MultiIndex'
    'texture_rating': ['min'],
    'flavor_rating': 'max',
    'total_rating': 'mean'
})
# Out:
#             texture_rating flavor_rating total_rating
#                        min           max         mean
# base_flavor
# Chocolate              7.0           8.8        15.70
# Vanilla                3.4          10.0        11.35

# %%
# With multi group
df.groupby(['base_flavor', 'liked']).agg({
    'texture_rating': 'mean',
    'flavor_rating': 'mean',
    'total_rating': ['count', 'min', 'max', 'sum', 'mean']
})
# Out:
#                   texture_rating flavor_rating total_rating                    \
#                             mean          mean        count   min   max   sum
# base_flavor liked
# Chocolate   Yes         7.233333           8.4            3  15.2  16.6  47.1
# Vanilla     No          4.466667           3.6            3   5.7   9.7  24.2
#             Yes         6.833333           7.8            3  12.5  18.0  43.9
#
#
#                         mean
# base_flavor liked
# Chocolate   Yes    15.700000
# Vanilla     No      8.066667
#             Yes    14.633333
