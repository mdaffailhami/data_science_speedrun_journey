# %%
from utils import display_pdf

display_pdf('exercises.pdf')
# Out:
# <wand.image.Image: aea538c 'PDF' (595x842)>
# <wand.image.Image: e8de38a 'PDF' (595x842)>
# <wand.image.Image: 24586ec 'PDF' (595x842)>
# <wand.image.Image: 90ab29a 'PDF' (595x842)>
